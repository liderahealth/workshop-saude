# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
db = pd.read_csv('seguro saúde - insurance.csv')

# %%
db.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.pairplot(db)

# %%
sns.scatterplot(x=db["age"], y=db['charges'], hue=db['smoker'])

# %%
sns.scatterplot(x=db["age"], y=db['charges'], hue=db['bmi'], hue_norm=(10,40,20))

# %%
sns.scatterplot(x=db["smoker"], y=db['charges'], hue=db['bmi'], hue_norm=(10,40,20))

# %%
sns.scatterplot(x=db["bmi"], y=db['charges'], hue=db['smoker'])

# %%
sns.scatterplot(x=db["bmi"], y=db['charges'], hue=db['age'])

# %%
db.groupby("age").describe()
# Out:
#       bmi                       ...       charges
#     count       mean       std  ...           50%           75%          max
# age                             ...
# 18   69.0  31.326159  6.970188  ...   2198.189850  11272.331390  38792.68560
# 19   68.0  28.596912  5.859832  ...   2135.891875  17148.980075  39722.74620
# 20   29.0  30.632759  4.629494  ...   2459.720100  17085.267600  38344.56600
# 21   28.0  28.185714  6.329480  ...   2254.423600   3205.349713  26018.95052
# 22   28.0  31.087679  6.964901  ...   2641.155700   4078.134675  44501.39820
# 23   28.0  31.454464  7.303742  ...   3594.538000  19145.024148  40904.19950
# 24   28.0  29.142679  4.889182  ...   3045.137650  17508.424985  38126.24650
# 25   28.0  29.693929  6.127734  ...   3750.148925  16333.214445  42112.23560
# 26   28.0  29.428929  6.883321  ...   3388.882175   3983.464100  36085.21900
# 27   28.0  29.333571  6.481367  ...   4544.324475  18262.557125  39611.75770
# ...

# %%
db.groupby("smoker").describe()
# Out:
#            age                        ...      charges
#          count       mean        std  ...          50%           75%          max
# smoker                                ...
# no      1064.0  39.385338  14.083410  ...   7345.40530  11362.887050  36910.60803
# yes      274.0  38.514599  13.923186  ...  34456.34845  41019.207275  63770.42801
#
# [2 rows x 32 columns]

# %%
smoker = db[db['smoker'] == 'yes']

# %%
sns.scatterplot(x=smoker["bmi"], y=smoker['charges'])

# %%
nonsmoker = db[db['smoker'] == 'no']

# %%
sns.scatterplot(x=nonsmoker["bmi"], y=nonsmoker['charges'])

# %%
male = db[db['sex'] == 'male']

# %%
female = db[db['sex'] == 'female']

# %%
sns.scatterplot(x=male["bmi"], y=male['charges'])

# %%
sns.scatterplot(x=female["bmi"], y=female['charges'])

# %%
sns.scatterplot(x=male["age"], y=male['charges'])

# %%
sns.scatterplot(x=female["age"], y=female['charges'])

# %%
sns.scatterplot(x=male["children"], y=male['charges'])

# %%
sns.scatterplot(x=female["children"], y=female['charges'])

# %%
db[db['children'] > 3].groupby("children").describe()
# Out:
#            age                        ...      charges
#          count       mean        std  ...          50%           75%        max
# children                              ...
# 4         25.0  39.000000  12.138094  ...  11033.66170  17128.426080  40182.246
# 5         18.0  35.611111  10.123583  ...   8589.56505  10019.943975  19023.260
#
# [2 rows x 24 columns]

# %%
y = nonsmoker["charges"]

# %%
x = nonsmoker[["age", "bmi"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([266.56054576,   7.53157352])

# %%
predicao = lm.predict(x_test)

# %%
plt.scatter(y_test, predicao)
plt.grid()

# %%
metrics.r2_score(y_test, predicao)
# Out:
# 0.34746132242165617

# %%
smoker30 = smoker[smoker['bmi'] > 30]

# %%
smoker30.head()
# Out:
#     age     sex    bmi  children smoker     region     charges
# 14   27    male  42.13         0    yes  southeast  39611.7577
# 19   30    male  35.30         0    yes  southwest  36837.4670
# 23   34  female  31.92         1    yes  northeast  37701.8768
# 29   31    male  36.30         2    yes  southwest  38711.0000
# 30   22    male  35.60         0    yes  southwest  35585.5760

# %%
y = smoker30["charges"]

# %%
x = smoker30[["age", "bmi"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([288.87637909, 540.24818042])

# %%
predicao = lm.predict(x_test)

# %%
plt.scatter(y_test, predicao)
plt.grid()

# %%
from sklearn import metrics

# %%
print('MSE:', metrics.mean_squared_error(y_test, predicao))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predicao)))
# Out:
# MSE: 8432647.404656311
# RMSE: 2903.9020997024522

# %%
metrics.r2_score(y_test, predicao)
# Out:
# 0.6497964271893475

# %%
smoker0 = smoker[smoker['bmi'] < 30]

# %%
y = smoker0["charges"]

# %%
x = smoker0[["age", "bmi"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([255.4297849 , 362.17890594])

# %%
predicao = lm.predict(x_test)

# %%
plt.scatter(y_test, predicao)
plt.grid()

# %%
print('MSE:', metrics.mean_squared_error(y_test, predicao))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predicao)))
# Out:
# MSE: 17088450.510903493
# RMSE: 4133.8179097419725

# %%
metrics.r2_score(y_test, predicao)
# Out:
# 0.42350380275350763
